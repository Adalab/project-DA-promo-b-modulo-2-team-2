# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import sidetable

# %%
df = pd.read_csv('./datos/HU2.csv', index_col=0)

# %%
df.head()
# Out:
#    index         q3                       q5          q6      q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
# 2      2   Pakistan        Software Engineer   1-3 years  Python
# 3      3     Mexico       Research Scientist   20+ years  Python
# 4      4      India                    Other   < 1 years  Python
#
#                                                  q11                 q13  \
# 0                                           A laptop           2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...               Never
# 2                                           A laptop               Never
# 3  A cloud computing platform (AWS, Azure, GCP, h...  More than 25 times
# 4  A cloud computing platform (AWS, Azure, GCP, h...               Never
#
#                                      q15  \
# 0                             5-10 years
# 1                               < 1 year
# 2  I do not use machine learning methods
# 3                             5-10 years
# 4                            10-20 years
#
#                                                  q23     q33  ...  \
# 0                      No (we do not use ML methods)     NaN  ...
# 1  We are exploring ML methods (and may one day p...     NaN  ...
# 2                                      I do not know  MySQL   ...
# 3                                      I do not know     NaN  ...
# 4  We use ML methods for generating insights (but...     NaN  ...
#
#                               q27                                  q29  \
# 0   Google Cloud Platform (GCP) ,        Google Cloud Compute Engine ,
# 1                             NaN                                  NaN
# 2                           None,                                  NaN
# 3                             NaN                                  NaN
# 4               Microsoft Azure ,   Microsoft Azure Virtual Machines ,
#
#                                    q30                               q31  \
# 0       Google Cloud Storage (GCS)   ,                        No / None,
# 1                                  NaN                               NaN
# 2                                  NaN                        DataRobot,
# 3                                  NaN                               NaN
# 4  Microsoft Azure Data Lake Storage ,   Azure Machine Learning Studio ,
#
#           q36  q37                  q38                               q39  \
# 0  No / None,  NaN           No / None,                 GitHub , Kaggle ,
# 1         NaN  NaN                  NaN                               NaN
# 2  No / None,  NaN           No / None,  I do not share my work publicly,
# 3         NaN  NaN                  NaN                               NaN
# 4  No / None,  NaN   Weights & Biases ,  I do not share my work publicly,
#
#                                                  q40  \
# 0  Coursera,edX,Kaggle Learn Courses,DataCamp,Uda...
# 1  Kaggle Learn Courses,Cloud-certification progr...
# 2                                          DataCamp,
# 3                                      Coursera,edX,
# 4                        Kaggle Learn Courses,Udemy,
#
#                                                  q42
# 0  Email newsletters (Data Elixir, O'Reilly Data ...
# 1  Journal Publications (peer-reviewed journals, ...
# 2  Kaggle (notebooks, forums, etc),YouTube (Kaggl...
# 3  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 4  Journal Publications (peer-reviewed journals, ...
#
# [5 rows x 32 columns]

# %%
df['q5'].unique()
# Out:
# array(['Other', 'Program/Project Manager', 'Software Engineer',
#        'Research Scientist', 'Currently not employed', 'Student',
#        'Data Scientist', 'Data Analyst', 'Machine Learning Engineer',
#        'Business Analyst', 'Data Engineer', 'Product Manager',
#        'Statistician', 'Developer Relations/Advocacy',
#        'DBA/Database Engineer'], dtype=object)

# %%
df_analyst = df[df['q5']=='Data Analyst']

# %%
df_analyst
# Out:
#        index                        q3            q5         q6      q8  \
# 16        16                   Belgium  Data Analyst  20+ years  Python
# 32        32  United States of America  Data Analyst  < 1 years       R
# 33        33                     Egypt  Data Analyst  3-5 years       R
# 46        46                     China  Data Analyst  < 1 years  Python
# 52        52              South Africa  Data Analyst  1-3 years       R
# ...      ...                       ...           ...        ...     ...
# 25954  25954                     India  Data Analyst  < 1 years  Python
# 25959  25959                     India  Data Analyst  1-3 years  Python
# 25965  25965                     India  Data Analyst  1-3 years  Python
# 25966  25966                     India  Data Analyst  1-3 years  Python
# 25968  25968                     Egypt  Data Analyst  1-3 years  Python
#
#                                                      q11        q13  \
# 16                                              A laptop      Never
# 32                         A personal computer / desktop      Never
# 33                                              A laptop      Never
# 46                         A personal computer / desktop  2-5 times
# 52                                              A laptop      Never
# ...                                                  ...        ...
# 25954                                           A laptop      Never
# 25959                      A personal computer / desktop      Never
# 25965                      A personal computer / desktop  2-5 times
# 25966  A cloud computing platform (AWS, Azure, GCP, h...       Once
# 25968                                           A laptop      Never
#
#                                          q15  \
# 16                                 1-2 years
# 32     I do not use machine learning methods
# 33     I do not use machine learning methods
# 46                                 1-2 years
# 52                                 1-2 years
# ...                                      ...
# 25954                              1-2 years
# 25959                               < 1 year
# 25965                              2-3 years
# 25966                              1-2 years
# 25968                              1-2 years
#
#                                                      q23       q33  ...  \
# 16     We are exploring ML methods (and may one day p...       NaN  ...
# 32                                                   NaN       NaN  ...
# 33                         No (we do not use ML methods)       NaN  ...
# 46                         No (we do not use ML methods)       NaN  ...
# 52                         No (we do not use ML methods)       NaN  ...
# ...                                                  ...       ...  ...
# 25954  We are exploring ML methods (and may one day p...       NaN  ...
# 25959  We are exploring ML methods (and may one day p...       NaN  ...
# 25965                                                NaN       NaN  ...
# 25966  We have well established ML methods (i.e., mod...       NaN  ...
# 25968  We are exploring ML methods (and may one day p...  MongoDB   ...
#
#                                                   q27  \
# 16                                                NaN
# 32                                                NaN
# 33                                              None,
# 46                                                NaN
# 52                              IBM Cloud / Red Hat ,
# ...                                               ...
# 25954                                             NaN
# 25959                                             NaN
# 25965                                             NaN
# 25966                                             NaN
# 25968   Amazon Web Services (AWS) , Microsoft Azure ,
#
#                                                      q29  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954                                                NaN
# 25959                                                NaN
# 25965                                                NaN
# 25966                                                NaN
# 25968   Amazon Elastic Compute Cloud (EC2) , Microsof...
#
#                                                      q30  \
# 16                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 46                                                   NaN
# 52                                                   NaN
# ...                                                  ...
# 25954                                                NaN
# 25959                                                NaN
# 25965                                                NaN
# 25966                                                NaN
# 25968   Amazon Simple Storage Service (S3)  , Amazon ...
#
#                                    q31         q36  q37             q38  \
# 16                                 NaN         NaN  NaN             NaN
# 32                                 NaN         NaN  NaN             NaN
# 33                          No / None,  No / None,  NaN      No / None,
# 46                                 NaN         NaN  NaN             NaN
# 52                          No / None,  No / None,  NaN      No / None,
# ...                                ...         ...  ...             ...
# 25954                              NaN         NaN  NaN             NaN
# 25959                              NaN         NaN  NaN             NaN
# 25965                              NaN         NaN  NaN             NaN
# 25966                              NaN         NaN  NaN             NaN
# 25968   Amazon SageMaker , Databricks,  No / None,  NaN   TensorBoard ,
#
#                                     q39  \
# 16                                  NaN
# 32                                  NaN
# 33     I do not share my work publicly,
# 46                                  NaN
# 52     I do not share my work publicly,
# ...                                 ...
# 25954                               NaN
# 25959                               NaN
# 25965                               NaN
# 25966                               NaN
# 25968                  GitHub , Colab ,
#
#                                                      q40  \
# 16     Coursera,Kaggle Learn Courses,Cloud-certificat...
# 32                                                   NaN
# 33     Coursera,Kaggle Learn Courses,DataCamp,Univers...
# 46                    Coursera,edX,Kaggle Learn Courses,
# 52                                       Coursera,Udemy,
# ...                                                  ...
# 25954                                          Coursera,
# 25959  Coursera,edX,Udacity,Udemy,Cloud-certification...
# 25965                                                NaN
# 25966                                                NaN
# 25968  Coursera,Kaggle Learn Courses,DataCamp,Udacity...
#
#                                                      q42
# 16     Kaggle (notebooks, forums, etc),Blogs (Towards...
# 32                                                   NaN
# 33     Twitter (data science influencers),Email newsl...
# 46     Twitter (data science influencers),Kaggle (not...
# 52     Course Forums (forums.fast.ai, Coursera forums...
# ...                                                  ...
# 25954                                                NaN
# 25959  Twitter (data science influencers),Email newsl...
# 25965                                                NaN
# 25966                                                NaN
# 25968  Kaggle (notebooks, forums, etc),YouTube (Kaggl...
#
# [2301 rows x 32 columns]

# %%
df.to_csv('./datos/data_analyst.csv')
