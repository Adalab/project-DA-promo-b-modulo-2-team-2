# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import sidetable

# %%
df = pd.read_csv('./datos/HU2.csv', index_col=0)

# %%
df["q23"].unique()
# Out:
# array(['No (we do not use ML methods)',
#        'We are exploring ML methods (and may one day put a model into production)',
#        'I do not know',
#        'We use ML methods for generating insights (but do not put working models into production)',
#        nan,
#        'We have well established ML methods (i.e., models in production for more than 2 years)',
#        'We recently started using ML methods (i.e., models in production for less than 2 years)'],
#       dtype=object)

# %%
df.head()
# Out:
#    index         q3                       q5          q6      q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
# 2      2   Pakistan        Software Engineer   1-3 years  Python
# 3      3     Mexico       Research Scientist   20+ years  Python
# 4      4      India                    Other   < 1 years  Python
#
#                                                  q11                 q13  \
# 0                                           A laptop           2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...               Never
# 2                                           A laptop               Never
# 3  A cloud computing platform (AWS, Azure, GCP, h...  More than 25 times
# 4  A cloud computing platform (AWS, Azure, GCP, h...               Never
#
#                                      q15  \
# 0                             5-10 years
# 1                               < 1 year
# ...

# %%
df['q5'].unique()
# Out:
# array(['Other', 'Program/Project Manager', 'Software Engineer',
#        'Research Scientist', 'Currently not employed', 'Student',
#        'Data Scientist', 'Data Analyst', 'Machine Learning Engineer',
#        'Business Analyst', 'Data Engineer', 'Product Manager',
#        'Statistician', 'Developer Relations/Advocacy',
#        'DBA/Database Engineer'], dtype=object)

# %%
df_analyst = df[df['q5']=='Data Analyst']

# %%
df_analyst_final= df_analyst[df_analyst['q6'].isin(['I have never written code', '< 1 years', '1-2 years'])]
df_analyst_final
# Out:
#        index                        q3            q5         q6      q8  \
# 32        32  United States of America  Data Analyst  < 1 years       R
# 46        46                     China  Data Analyst  < 1 years  Python
# 66        66                     China  Data Analyst  < 1 years  Python
# 102      102                     India  Data Analyst  < 1 years  Python
# 108      108                    Israel  Data Analyst  < 1 years  Python
# ...      ...                       ...           ...        ...     ...
# 25811  25811                    Russia  Data Analyst  < 1 years  Python
# 25819  25819                  Pakistan  Data Analyst  < 1 years     SQL
# 25909  25909                     India  Data Analyst  < 1 years  Python
# 25916  25916                  Pakistan  Data Analyst  < 1 years  Python
# 25954  25954                     India  Data Analyst  < 1 years  Python
#
#                                  q11        q13  \
# 32     A personal computer / desktop      Never
# ...

# %%
df_analyst_final.to_csv('./datos/data_analyst.csv')
