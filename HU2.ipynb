# %% [markdown]
# Continuamos con la limpieza y depuración de las columnas

# %%
import pandas as pd
import numpy as np 
import sidetable 
import re

pd.options.display.max_columns = None

# %%
df = pd.read_csv("datos/columnas_def.csv", index_col = 0)
df.head()
# Out:
#    index         Q3                       Q5          Q6      Q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
# 2      2   Pakistan        Software Engineer   1-3 years  Python
# 3      3     Mexico       Research Scientist   20+ years  Python
# 4      4      India                    Other   < 1 years  Python
#
#                                                  Q11                 Q13  \
# 0                                           A laptop           2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...               Never
# 2                                           A laptop               Never
# 3  A cloud computing platform (AWS, Azure, GCP, h...  More than 25 times
# 4  A cloud computing platform (AWS, Azure, GCP, h...               Never
#
#                                      Q15  \
# 0                             5-10 years
# 1                               < 1 year
# ...

# %% [markdown]
# Creamos una función para que nos elimine los espacios en blanco de todas las columnas de nuestro Dataframe

# %%
def whitespace_remover(df):
   
    
    try:
        
        for i in df.columns:
         
        
            if df[i].dtype == 'object':
             
            
                df[i] = df[i].map(str.strip)
        else: 
            pass
                
    except:
        pass
whitespace_remover(df)
 

df.head(2)
# Out:
#    index         Q3                       Q5          Q6      Q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
#
#                                                  Q11        Q13         Q15  \
# 0                                           A laptop  2-5 times  5-10 years
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never    < 1 year
#
#                                                  Q23  Q33  \
# 0                      No (we do not use ML methods)  NaN
# 1  We are exploring ML methods (and may one day p...  NaN
#
#                                                  Q41                  Q7  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                             Q9                 Q12  \
# 0                  Vim / Emacs  Google Cloud TPUs
# ...

# %% [markdown]
# Reemplazamos los "numpy nan" de nuestro Dataframe por "null"

# %%
df = df.replace(np.nan,"null")

columnas = ["Q10","Q18", "Q19","Q27","Q29", "Q30", "Q31", "Q32", "Q34", "Q36", "Q37", "Q38","Q39", "Q40", "Q42"]

for values in columnas:
    columnas_juntar = [x for x in list(df.columns.values) if values in x]
    df[values] = df[columnas_juntar].agg("?".join, axis = 1)
    df = df.drop(columns = columnas_juntar)

# %% [markdown]
# Para ello creamos un patrón con Regex

# %%
patron = "null(,|s|.*)"

df.replace(to_replace=patron, value='', regex=True,inplace=True)

# %% [markdown]
#  - Vamos a reducir la descripción de las respuestas, sin especificar lo que contienen dentro de los paréntesis ya que luego nos da problemas a la hora de unir y separar por coma.
#
#  - Visual Studio Code (VSCode) --> Visual Studio
#
#  - Jupyter (JupyterLab, Jupyter Notebooks, etc) --> Jupyter
#
#  - A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc) --> A cloud computing platform
#
#  - A deep learning workstation (NVIDIA GTX, LambdaLabs, etc) --> A deep learning workstation

# %%
patron2 = "\(.*\)"
df["Q9"].replace(to_replace=patron2, value='', regex=True,inplace=True)
df["Q11"].replace(to_replace=patron2, value='', regex=True,inplace=True)

# %% [markdown]
# Verificamos que hemos hecho bien el replace de "null"

# %%
df['Q40'].unique()
# Out:
# array(['Coursera?edX?Kaggle Learn Courses?DataCamp?', '', 'Coursera?edX?',
#        'Coursera?', 'Coursera?edX?Kaggle Learn Courses?',
#        'Coursera?edX?Kaggle Learn Courses?DataCamp?Fast.ai?Udacity?Udemy?',
#        'Coursera?edX?Kaggle Learn Courses?DataCamp?Fast.ai?Udacity?Udemy?LinkedIn Learning?Cloud-certification programs (direct from AWS, Azure, GCP, or similar)?University Courses (resulting in a university degree)?',
#        'Coursera?edX?Kaggle Learn Courses?DataCamp?Fast.ai?',
#        'Coursera?edX?Kaggle Learn Courses?DataCamp?Fast.ai?Udacity?Udemy?LinkedIn Learning?',
#        'Coursera?edX?Kaggle Learn Courses?DataCamp?Fast.ai?Udacity?',
#        'Coursera?edX?Kaggle Learn Courses?DataCamp?Fast.ai?Udacity?Udemy?LinkedIn Learning?Cloud-certification programs (direct from AWS, Azure, GCP, or similar)?'],
#       dtype=object)

# %%
df_columnas_nuevas = {col: col.strip().replace(" ","_").lower() for col in df.columns}
df.rename(columns = df_columnas_nuevas, inplace = True)

# %% [markdown]
# Comprobamos que no tenemos duplicados

# %%
df["index"].duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    index         q3                       q5          q6      q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
# 2      2   Pakistan        Software Engineer   1-3 years  Python
# 3      3     Mexico       Research Scientist   20+ years  Python
# 4      4      India                    Other   < 1 years  Python
#
#                            q11                 q13  \
# 0                     A laptop           2-5 times
# 1  A cloud computing platform                Never
# 2                     A laptop               Never
# 3  A cloud computing platform   More than 25 times
# 4  A cloud computing platform                Never
#
#                                      q15  \
# 0                             5-10 years
# 1                               < 1 year
# 2  I do not use machine learning methods
# 3                             5-10 years
# 4                            10-20 years
#
# ...

# %%
pd.options.display.max_rows = None

# %%
df['q40'].value_counts()
# Out:
#                                                                                                                                                                                                                     16324
# Coursera?                                                                                                                                                                                                            7309
# Coursera?edX?                                                                                                                                                                                                         912
# Coursera?edX?Kaggle Learn Courses?                                                                                                                                                                                    710
# ...

# %%
nulos = df.isna().sum()
nulos
# Out:
# index    0
# q3       0
# q5       0
# q6       0
# q8       0
# q11      0
# q13      0
# q15      0
# q23      0
# q33      0
# q41      0
# q7       0
# q9       0
# q12      0
# q14      0
# q16      0
# q17      0
# q24      0
# q28      0
# q10      0
# q18      0
# q19      0
# q27      0
# q29      0
# q30      0
# q31      0
# q36      0
# q37      0
# q38      0
# q39      0
# q40      0
# q42      0
# dtype: int64

# %%
df_q9 = df.stb.freq(['q9'])

# %%
df.describe(include = ['O']).T
# Out:
#      count unique                    top   freq
# q3   25973     66                  India   7434
# q5   25973     15                Student   6804
# q6   25973      7              1-3 years   7874
# q8   25973     14                 Python  20213
# q11  25973      7               A laptop  16231
# q13  25973      6                  Never  16457
# q15  25973     10               < 1 year   9163
# q23  25973      7                         10021
# q33  25973     21                         21317
# q41  25973      7                          7484
# q7   25973    826                 Python   4740
# q9   25973   1055       Jupyter Notebook   2341
# q12  25973     27                   None  13234
# q14  25973    468   Matplotlib ,Seaborn    5697
# q16  25973   1402                          6349
# q17  25973    757                          6658
# q24  25973     97                         10338
# q28  25973     14                         22846
# q10  25973      9                         16466
# ...

# %% [markdown]
# Guardamos todo lo trabajado en un archivo csv bajo el nombre de HU2.csv

# %%
df.to_csv('./datos/HU2.csv')
