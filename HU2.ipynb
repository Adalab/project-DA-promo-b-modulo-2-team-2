# %%
import pandas as pd
import numpy as np 
import sidetable 

pd.options.display.max_columns = None

# %%
df = pd.read_csv("datos/columnas_def.csv", index_col = 0)
df.head()
# Out:
#    index         Q3                       Q5          Q6      Q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
# 2      2   Pakistan        Software Engineer   1-3 years  Python
# 3      3     Mexico       Research Scientist   20+ years  Python
# 4      4      India                    Other   < 1 years  Python
#
#                                                  Q11                 Q13  \
# 0                                           A laptop           2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...               Never
# 2                                           A laptop               Never
# 3  A cloud computing platform (AWS, Azure, GCP, h...  More than 25 times
# 4  A cloud computing platform (AWS, Azure, GCP, h...               Never
#
#                                      Q15  \
# 0                             5-10 years
# 1                               < 1 year
# ...

# %%
def whitespace_remover(df):
   
    # iterating over the columns
    try:
        
        for i in df.columns:
         
        # checking datatype of each columns
            if df[i].dtype == 'object':
             
            # applying strip function on column
                df[i] = df[i].map(str.strip)
        else: 
            pass
                
    except:
        pass
# applying whitespace_remover function on dataframe
whitespace_remover(df)
 
# printing dataframe
df.head(2)
# Out:
#    index         Q3                       Q5          Q6      Q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
#
#                                                  Q11        Q13         Q15  \
# 0                                           A laptop  2-5 times  5-10 years
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never    < 1 year
#
#                                                  Q23  Q33  \
# 0                      No (we do not use ML methods)  NaN
# 1  We are exploring ML methods (and may one day p...  NaN
#
#                                                  Q41                  Q7  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                             Q9                 Q12  \
# 0                  Vim / Emacs  Google Cloud TPUs
# ...

# %%
df = df.replace(np.nan,"null")

columnas = ["Q10","Q18", "Q19","Q27","Q29", "Q30", "Q31", "Q32", "Q34", "Q36", "Q37", "Q38","Q39", "Q40", "Q42"]

for values in columnas:
    columnas_juntar = [x for x in list(df.columns.values) if values in x]
    df[values] = df[columnas_juntar].agg(",".join, axis = 1)
    df = df.drop(columns = columnas_juntar)

# %%
patron = "null(,|s|.*)"

df.replace(to_replace=patron, value='', regex=True,inplace=True)

# %%
# Probando que hemos hecho bien el replace de "null"
df['Q40'].unique()
# Out:
# array(['Coursera,edX,Kaggle Learn Courses,DataCamp,Udacity,Udemy,',
#        'Kaggle Learn Courses,Cloud-certification programs (direct from AWS, Azure, GCP, or similar),University Courses (resulting in a university degree),',
#        'DataCamp,', 'Coursera,edX,', 'Kaggle Learn Courses,Udemy,',
#        'Cloud-certification programs (direct from AWS, Azure, GCP, or similar),',
#        '', 'Coursera,Kaggle Learn Courses,Udemy,LinkedIn Learning,',
#        'Kaggle Learn Courses,', 'Udemy,',
#        'DataCamp,Udemy,University Courses (resulting in a university degree),',
#        'Coursera,edX,DataCamp,',
#        'Coursera,edX,Kaggle Learn Courses,DataCamp,Udemy,', 'Coursera,',
#        'Coursera,Udacity,University Courses (resulting in a university degree),',
#        'Coursera,Kaggle Learn Courses,Cloud-certification programs (direct from AWS, Azure, GCP, or similar),',
#        'Coursera,DataCamp,Udacity,LinkedIn Learning,University Courses (resulting in a university degree),',
# ...

# %%
df_columnas_nuevas = {col: col.strip().replace(" ","_").lower() for col in df.columns}
df.rename(columns = df_columnas_nuevas, inplace = True)

# %%
df["index"].duplicated().sum() #Comprobando que no tenemos duplicados
# Out:
# 0

# %%
df.head()
# Out:
#    index         q3                       q5          q6      q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
# 2      2   Pakistan        Software Engineer   1-3 years  Python
# 3      3     Mexico       Research Scientist   20+ years  Python
# 4      4      India                    Other   < 1 years  Python
#
#                                                  q11                 q13  \
# 0                                           A laptop           2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...               Never
# 2                                           A laptop               Never
# 3  A cloud computing platform (AWS, Azure, GCP, h...  More than 25 times
# 4  A cloud computing platform (AWS, Azure, GCP, h...               Never
#
#                                      q15  \
# 0                             5-10 years
# 1                               < 1 year
# ...

# %%
pd.options.display.max_rows = None

# %%
nulos = df.isna().sum()
nulos
# Out:
# index    0
# q3       0
# q5       0
# q6       0
# q8       0
# q11      0
# q13      0
# q15      0
# q23      0
# q33      0
# q41      0
# q7       0
# q9       0
# q12      0
# q14      0
# q16      0
# q17      0
# q24      0
# q28      0
# q10      0
# q18      0
# q19      0
# q27      0
# q29      0
# q30      0
# q31      0
# q36      0
# q37      0
# q38      0
# q39      0
# q40      0
# q42      0
# dtype: int64

# %%
df_q9 = df.stb.freq(['q9'])
# Out:
#                                                      q9  count   percent  \
# 0                                      Jupyter Notebook   2341  9.013206
# 1         Visual Studio Code (VSCode) ,Jupyter Notebook   1412  5.436415
# 2                                                         1039  4.000308
# 3                          Visual Studio Code (VSCode)     939  3.615293
# 4                             PyCharm ,Jupyter Notebook    820  3.157125
# 5     Visual Studio Code (VSCode) ,PyCharm ,Jupyter ...    554  2.132984
# 6                                              PyCharm     553  2.129134
# 7                                                  None    526  2.025180
# 8                             RStudio ,Jupyter Notebook    524  2.017480
# 9                                              RStudio     502  1.932776
# 10                              Spyder,Jupyter Notebook    387  1.490009
# 11    Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...    384  1.478458
# ...

# %%
df.describe(include = ['O']).T
# Out:
#      count unique                    top   freq
# q3   25973     66                  India   7434
# q5   25973     15                Student   6804
# q6   25973      7              1-3 years   7874
# q8   25973     14                 Python  20213
# q11  25973      7               A laptop  16231
# q13  25973      6                  Never  16457
# q15  25973     10               < 1 year   9163
# q23  25973      7                         10021
# q33  25973     21                         21317
# q41  25973      7                          7484
# q7   25973    826                 Python   4740
# q9   25973   1331       Jupyter Notebook   2341
# q12  25973     27                   None  13234
# q14  25973    468   Matplotlib ,Seaborn    5697
# q16  25973   1402                          6349
# q17  25973    757                          6658
# q24  25973     97                         10338
# q28  25973     14                         22846
# q10  25973    724                  None,   7174
# ...

# %%
#df.to_csv('./datos/HU2.csv')
