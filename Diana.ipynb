# %%
import pandas as pd
import numpy as np 
import sidetable 
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None 
df = pd.read_csv('./datos/data_analyst.csv', index_col = 0)
df.head()
# Out:
#      index                        q3            q5         q6      q8  \
# 32      32  United States of America  Data Analyst  < 1 years       R
# 46      46                     China  Data Analyst  < 1 years  Python
# 66      66                     China  Data Analyst  < 1 years  Python
# 102    102                     India  Data Analyst  < 1 years  Python
# 108    108                    Israel  Data Analyst  < 1 years  Python
#
#                                q11        q13  \
# 32   A personal computer / desktop      Never
# 46   A personal computer / desktop  2-5 times
# 66                        A laptop      Never
# 102                       A laptop       Once
# 108  A personal computer / desktop      Never
#
#                                        q15  \
# 32   I do not use machine learning methods
# 46                               1-2 years
# 66                                < 1 year
# 102                               < 1 year
# ...

# %%
plt.figure(figsize=(20,10))
fig= sns.histplot(x='q9', data=df_q9)
plt.title('Entorno de desarrollo integrado')
plt.xticks(rotation = 45)
fig.set(ylabel='Entornos', xlabel= 'Conteo');
# Out:
# [Text(0, 0.5, 'Entornos'), Text(0.5, 0, 'Conteo')]

# %%
plt.figure(figsize=(20,10))
fig=sns.countplot(data=df,y='q9',order=df['q9'].value_counts().iloc[:10].index)
plt.title('Entorno de desarrollo integrado')
plt.xticks(rotation = 45)
fig.set(ylabel='Entornos', xlabel= 'Conteo');

# %%
plt.figure(figsize=(20,10))
fig=sns.countplot(data=df,y='q3',order=df['q3'].value_counts().iloc[:10].index)
plt.title('Países de residencia')
plt.xticks(rotation = 45)
fig.set(ylabel='Herramientas', xlabel= 'Conteo');

# %%
plt.figure(figsize=(20,10))
fig=sns.countplot(data=df,y='q14',order=df['q14'].value_counts().iloc[:10].index)
plt.title('Librerías de visualización más usadas regularmente')
plt.xticks(rotation = 45)
fig.set(ylabel='Herramientas', xlabel= 'Conteo');

# %%
plt.figure(figsize=(20,10))
fig=sns.countplot(data=df,y='q16',order=df['q16'].value_counts().iloc[:10].index)
plt.title('Machine learning frameworks') #esto es más usado por los data scientist 
plt.xticks(rotation = 45)
fig.set(ylabel='Herramientas', xlabel= 'Conteo');
