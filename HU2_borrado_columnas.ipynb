# %% [markdown]
# Continuamos trabajando sobre nuestro Dataframe y eliminamos las columnas que no son relevantes para nuestro estudio

# %%
import pandas as pd
import numpy as np

# %%
df_completo = pd.read_csv("datos/df_unido.csv")
df_completo.head()
# Out:
#    Unnamed: 0  level_0  index  time    age gender         Q3  \
# 0           0        0      0   910  50-54    Man      India
# 1           1        1      1   784  50-54    Man  Indonesia
# 2           2        2      2   924  22-24    Man   Pakistan
# 3           3        3      3   575  45-49    Man     Mexico
# 4           4        4      4   781  45-49    Man      India
#
#                   Q4                       Q5          Q6  ... Q38_B_Part_3  \
# 0  Bachelor’s degree                    Other  5-10 years  ...          NaN
# 1    Master’s degree  Program/Project Manager   20+ years  ...          NaN
# 2    Master’s degree        Software Engineer   1-3 years  ...          NaN
# 3    Doctoral degree       Research Scientist   20+ years  ...          NaN
# 4    Doctoral degree                    Other   < 1 years  ...          NaN
#
#   Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7 Q38_B_Part_8  \
# 0          NaN            NaN          NaN          NaN          NaN
# 1          NaN            NaN          NaN          NaN          NaN
# 2          NaN   TensorBoard           NaN          NaN          NaN
# 3          NaN            NaN          NaN          NaN          NaN
# 4          NaN            NaN          NaN          NaN          NaN
#
#   Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 0          NaN           NaN           NaN         NaN
# 1          NaN           NaN          None         NaN
# 2          NaN           NaN           NaN         NaN
# 3          NaN           NaN          None         NaN
# 4          NaN           NaN           NaN         NaN
#
# [5 rows x 261 columns]

# %%
columnas_eliminar= ['Unnamed: 0','level_0','time','age','gender','Q4','Q20','Q21','Q22','Q25','Q26','Q27_B_Part_1','Q27_B_Part_2','Q27_B_Part_3','Q27_B_Part_4','Q27_B_Part_5','Q27_B_Part_6','Q27_B_Part_7','Q27_B_Part_8','Q27_B_Part_9','Q27_B_Part_10','Q27_B_Part_11','Q27_B_OTHER','Q35','Q29_B_Part_1','Q29_B_Part_2','Q29_B_Part_3','Q29_B_Part_4','Q29_B_OTHER','Q30_B_Part_1','Q30_B_Part_2','Q30_B_Part_3','Q30_B_Part_4','Q30_B_Part_5','Q30_B_Part_6','Q30_B_Part_7','Q30_B_OTHER','Q31_B_Part_1','Q31_B_Part_2','Q31_B_Part_3','Q31_B_Part_4','Q31_B_Part_5','Q31_B_Part_6','Q31_B_Part_7','Q31_B_Part_8','Q31_B_Part_9','Q31_B_OTHER','Q32_B_Part_1','Q32_B_Part_2','Q32_B_Part_3','Q32_B_Part_4','Q32_B_Part_5','Q32_B_Part_6','Q32_B_Part_7','Q32_B_Part_8','Q32_B_Part_9','Q32_B_Part_10','Q32_B_Part_11','Q32_B_Part_12','Q32_B_Part_13','Q32_B_Part_14','Q32_B_Part_15','Q32_B_Part_16','Q32_B_Part_17','Q32_B_Part_18','Q32_B_Part_19','Q32_B_Part_20','Q32_B_OTHER','Q34_B_Part_1','Q34_B_Part_2','Q34_B_Part_3','Q34_B_Part_4','Q34_B_Part_5','Q34_B_Part_6','Q34_B_Part_7','Q34_B_Part_8','Q34_B_Part_9','Q34_B_Part_10','Q34_B_Part_11','Q34_B_Part_12','Q34_B_Part_13','Q34_B_Part_14','Q34_B_Part_15','Q34_B_Part_16','Q34_B_OTHER','Q36_B_Part_1','Q36_B_Part_2','Q36_B_Part_3','Q36_B_Part_4','Q36_B_Part_5','Q36_B_Part_6','Q36_B_Part_7','Q36_B_OTHER','Q37_B_Part_1','Q37_B_Part_2','Q37_B_Part_3','Q37_B_Part_4','Q37_B_Part_5','Q37_B_Part_6','Q37_B_Part_7','Q37_B_OTHER','Q38_B_Part_1','Q38_B_Part_2','Q38_B_Part_3','Q38_B_Part_4','Q38_B_Part_5','Q38_B_Part_6','Q38_B_Part_7','Q38_B_Part_8','Q38_B_Part_9','Q38_B_Part_10','Q38_B_Part_11','Q38_B_OTHER']

# %%
df= df_completo.drop(columns = columnas_eliminar, axis = 0)

# %%
df.head()
# Out:
#    index         Q3                       Q5          Q6      Q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
# 2      2   Pakistan        Software Engineer   1-3 years  Python
# 3      3     Mexico       Research Scientist   20+ years  Python
# 4      4      India                    Other   < 1 years  Python
#
#                                                  Q11                 Q13  \
# 0                                           A laptop           2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...               Never
# 2                                           A laptop               Never
# 3  A cloud computing platform (AWS, Azure, GCP, h...  More than 25 times
# 4  A cloud computing platform (AWS, Azure, GCP, h...               Never
#
#                                      Q15  \
# 0                             5-10 years
# 1                               < 1 year
# 2  I do not use machine learning methods
# 3                             5-10 years
# 4                            10-20 years
#
#                                                  Q23     Q33  ... Q42_Part_3  \
# 0                      No (we do not use ML methods)     NaN  ...        NaN
# 1  We are exploring ML methods (and may one day p...     NaN  ...        NaN
# 2                                      I do not know  MySQL   ...        NaN
# 3                                      I do not know     NaN  ...        NaN
# 4  We use ML methods for generating insights (but...     NaN  ...        NaN
#
#                         Q42_Part_4 Q42_Part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
# 2  Kaggle (notebooks, forums, etc)        NaN
# 3                              NaN        NaN
# 4                              NaN        NaN
#
#                                           Q42_Part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
# 2  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 3  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 4                                                NaN
#
#                                           Q42_Part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q42_Part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
# 2                                                NaN
# 3  Blogs (Towards Data Science, Analytics Vidhya,...
# 4                                                NaN
#
#                                           Q42_Part_9 Q42_Part_10 Q42_Part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 2                                                NaN         NaN         NaN
# 3  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 4  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   Q42_OTHER
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 148 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Columns: 148 entries, index to Q42_OTHER
# dtypes: int64(1), object(147)
# memory usage: 29.3+ MB

# %%
df.describe(include = "object")
# Out:
#            Q3       Q5         Q6      Q8       Q11    Q13       Q15  \
# count   25973    25973      25973   24940     24720  24403     23754
# unique     66       15          7      13         6      5         9
# top     India  Student  1-3 years  Python  A laptop  Never  < 1 year
# freq     7434     6804       7874   20213     16231  16457      9163
#
#                                                       Q23     Q33  \
# count                                               15952    4656
# unique                                                  6      20
# top     We are exploring ML methods (and may one day p...  MySQL
# freq                                                 3390    1110
#
#                                                       Q41  ...  \
# count                                               18489  ...
# unique                                                  6  ...
# top     Basic statistical software (Microsoft Excel, G...  ...
# freq                                                 7246  ...
#
#                              Q42_Part_3                       Q42_Part_4  \
# count                              2939                            11373
# unique                                1                                1
# top     Reddit (r/machinelearning, etc)  Kaggle (notebooks, forums, etc)
# freq                               2939                            11373
#
#                                                Q42_Part_5  \
# count                                                2996
# unique                                                  1
# top     Course Forums (forums.fast.ai, Coursera forums...
# freq                                                 2996
#
#                                                Q42_Part_6  \
# count                                               10401
# unique                                                  1
# top     YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# freq                                                10401
#
#                                                Q42_Part_7  \
# count                                                2022
# unique                                                  1
# top     Podcasts (Chai Time Data Science, O’Reilly Dat...
# freq                                                 2022
#
#                                                Q42_Part_8  \
# count                                                7977
# unique                                                  1
# top     Blogs (Towards Data Science, Analytics Vidhya,...
# freq                                                 7977
#
#                                                Q42_Part_9  \
# count                                                3350
# unique                                                  1
# top     Journal Publications (peer-reviewed journals, ...
# freq                                                 3350
#
#                                          Q42_Part_10 Q42_Part_11 Q42_OTHER
# count                                           1995        1007       583
# unique                                             1           1         1
# top     Slack Communities (ods.ai, kagglenoobs, etc)        None     Other
# freq                                            1995        1007       583
#
# [4 rows x 147 columns]

# %%
df.describe()
# Out:
#               index
# count  25973.000000
# mean   12986.000000
# std     7497.903607
# min        0.000000
# 25%     6493.000000
# 50%    12986.000000
# 75%    19479.000000
# max    25972.000000

# %% [markdown]
# Vemos que tipo de datos tenemos en nuestro Dataframe

# %%
df.describe(include = "all")
# Out:
#                index     Q3       Q5         Q6      Q8       Q11    Q13  \
# count   25973.000000  25973    25973      25973   24940     24720  24403
# unique           NaN     66       15          7      13         6      5
# top              NaN  India  Student  1-3 years  Python  A laptop  Never
# freq             NaN   7434     6804       7874   20213     16231  16457
# mean    12986.000000    NaN      NaN        NaN     NaN       NaN    NaN
# std      7497.903607    NaN      NaN        NaN     NaN       NaN    NaN
# min         0.000000    NaN      NaN        NaN     NaN       NaN    NaN
# 25%      6493.000000    NaN      NaN        NaN     NaN       NaN    NaN
# 50%     12986.000000    NaN      NaN        NaN     NaN       NaN    NaN
# 75%     19479.000000    NaN      NaN        NaN     NaN       NaN    NaN
# max     25972.000000    NaN      NaN        NaN     NaN       NaN    NaN
#
#              Q15                                                Q23     Q33  \
# count      23754                                              15952    4656
# unique         9                                                  6      20
# top     < 1 year  We are exploring ML methods (and may one day p...  MySQL
# freq        9163                                               3390    1110
# mean         NaN                                                NaN     NaN
# std          NaN                                                NaN     NaN
# min          NaN                                                NaN     NaN
# 25%          NaN                                                NaN     NaN
# 50%          NaN                                                NaN     NaN
# 75%          NaN                                                NaN     NaN
# max          NaN                                                NaN     NaN
#
#         ...                       Q42_Part_3                       Q42_Part_4  \
# count   ...                             2939                            11373
# unique  ...                                1                                1
# top     ...  Reddit (r/machinelearning, etc)  Kaggle (notebooks, forums, etc)
# freq    ...                             2939                            11373
# mean    ...                              NaN                              NaN
# std     ...                              NaN                              NaN
# min     ...                              NaN                              NaN
# 25%     ...                              NaN                              NaN
# 50%     ...                              NaN                              NaN
# 75%     ...                              NaN                              NaN
# max     ...                              NaN                              NaN
#
#                                                Q42_Part_5  \
# count                                                2996
# unique                                                  1
# top     Course Forums (forums.fast.ai, Coursera forums...
# freq                                                 2996
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                Q42_Part_6  \
# count                                               10401
# unique                                                  1
# top     YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# freq                                                10401
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                Q42_Part_7  \
# count                                                2022
# unique                                                  1
# top     Podcasts (Chai Time Data Science, O’Reilly Dat...
# freq                                                 2022
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                Q42_Part_8  \
# count                                                7977
# unique                                                  1
# top     Blogs (Towards Data Science, Analytics Vidhya,...
# freq                                                 7977
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                Q42_Part_9  \
# count                                                3350
# unique                                                  1
# top     Journal Publications (peer-reviewed journals, ...
# freq                                                 3350
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          Q42_Part_10 Q42_Part_11 Q42_OTHER
# count                                           1995        1007       583
# unique                                             1           1         1
# top     Slack Communities (ods.ai, kagglenoobs, etc)        None     Other
# freq                                            1995        1007       583
# mean                                             NaN         NaN       NaN
# std                                              NaN         NaN       NaN
# min                                              NaN         NaN       NaN
# 25%                                              NaN         NaN       NaN
# 50%                                              NaN         NaN       NaN
# 75%                                              NaN         NaN       NaN
# max                                              NaN         NaN       NaN
#
# [11 rows x 148 columns]

# %% [markdown]
# Vemos el número de valores nulos que tenemos por columna

# %%
sonnulos = df.isnull().sum()
type(sonnulos)
# Out:
# pandas.core.series.Series

# %%
sonnulos
# Out:
# index              0
# Q3                 0
# Q5                 0
# Q6                 0
# Q8              1033
#                ...
# Q42_Part_8     17996
# Q42_Part_9     22623
# Q42_Part_10    23978
# Q42_Part_11    24966
# Q42_OTHER      25390
# Length: 148, dtype: int64

# %%
df.shape
# Out:
# (25973, 148)

# %%
df.head()
# Out:
#    index         Q3                       Q5          Q6      Q8  \
# 0      0      India                    Other  5-10 years  Python
# 1      1  Indonesia  Program/Project Manager   20+ years  Python
# 2      2   Pakistan        Software Engineer   1-3 years  Python
# 3      3     Mexico       Research Scientist   20+ years  Python
# 4      4      India                    Other   < 1 years  Python
#
#                                                  Q11                 Q13  \
# 0                                           A laptop           2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...               Never
# 2                                           A laptop               Never
# 3  A cloud computing platform (AWS, Azure, GCP, h...  More than 25 times
# 4  A cloud computing platform (AWS, Azure, GCP, h...               Never
#
#                                      Q15  \
# 0                             5-10 years
# 1                               < 1 year
# 2  I do not use machine learning methods
# 3                             5-10 years
# 4                            10-20 years
#
#                                                  Q23     Q33  ... Q42_Part_3  \
# 0                      No (we do not use ML methods)     NaN  ...        NaN
# 1  We are exploring ML methods (and may one day p...     NaN  ...        NaN
# 2                                      I do not know  MySQL   ...        NaN
# 3                                      I do not know     NaN  ...        NaN
# 4  We use ML methods for generating insights (but...     NaN  ...        NaN
#
#                         Q42_Part_4 Q42_Part_5  \
# 0  Kaggle (notebooks, forums, etc)        NaN
# 1                              NaN        NaN
# 2  Kaggle (notebooks, forums, etc)        NaN
# 3                              NaN        NaN
# 4                              NaN        NaN
#
#                                           Q42_Part_6  \
# 0  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1                                                NaN
# 2  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 3  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 4                                                NaN
#
#                                           Q42_Part_7  \
# 0  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q42_Part_8  \
# 0  Blogs (Towards Data Science, Analytics Vidhya,...
# 1                                                NaN
# 2                                                NaN
# 3  Blogs (Towards Data Science, Analytics Vidhya,...
# 4                                                NaN
#
#                                           Q42_Part_9 Q42_Part_10 Q42_Part_11  \
# 0  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 1  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 2                                                NaN         NaN         NaN
# 3  Journal Publications (peer-reviewed journals, ...         NaN         NaN
# 4  Journal Publications (peer-reviewed journals, ...         NaN         NaN
#
#   Q42_OTHER
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 148 columns]

# %% [markdown]
# De nuevo guardamos el archivo trabajado en un archivo csv como columnas_def.cvs para identificar que ya tenemos las columnas depuradas

# %%
df.to_csv('./datos/columnas_def.csv')
