# %%
import pandas as pd
import numpy as np

# %%
data_csv = pd.read_csv("datos/exported_db_data.csv")
data_csv.head()
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10  \
# 0        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN
#
#             Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15  \
# ...

# %%
data_csv.shape
# Out:
# (25973, 18)

# %%
kaggle_csv = pd.read_csv("datos/data_remaning_kaggle.csv",index_col=0)
kaggle_csv
# Out:
#        index                                         Q18_Part_1  \
# 0          0  General purpose image/video tools (PIL, cv2, s...
# 1          1                                                NaN
# 2          2                                                NaN
# 3          3  General purpose image/video tools (PIL, cv2, s...
# 4          4                                                NaN
# ...      ...                                                ...
# 25968  25968  General purpose image/video tools (PIL, cv2, s...
# 25969  25969                                                NaN
# 25970  25970                                                NaN
# 25971  25971                                                NaN
# 25972  25972                                                NaN
#
#                                               Q18_Part_2  \
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
kaggle_csv.shape
# Out:
# (25973, 214)

# %%
kaggle_csv.isna().sum()
# Out:
# index                0
# Q18_Part_1       23311
# Q18_Part_2       23233
# Q18_Part_3       23257
# Q18_Part_4       21600
#                  ...
# Q38_B_Part_8     24953
# Q38_B_Part_9     25307
# Q38_B_Part_10    23226
# Q38_B_Part_11    21431
# Q38_B_OTHER      25596
# Length: 213, dtype: int64

# %%
data_txt = pd.read_csv("./datos/data_txt_clean.txt", sep = ";")
data_txt.head()
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 3      3     Mexico    Doctoral degree       Research Scientist   20+ years
# 4      4      India    Doctoral degree                    Other   < 1 years
#
#        Q8                                                Q11  \
# 0  Python                                           A laptop
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2  Python                                           A laptop
# 3  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 4  Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                   Q13                                    Q15  \
# 0           2-5 times                             5-10 years
# ...

# %%
data_txt.shape
# Out:
# (25973, 27)

# %%
data_xml = pd.read_xml("./datos/data_xml_clean.xml")
data_xml.head()
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man
# 1        1      1   784  50-54    Man
# 2        2      2   924  22-24    Man
# 3        3      3   575  45-49    Man
# 4        4      4   781  45-49    Man

# %%
data_xml.shape
# Out:
# (25973, 5)

# %%
# visualizamos las columnas de los dataframes

data_csv.columns
# Out:
# Index(['index', 'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4',
#        'Q10_Part_5', 'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9',
#        'Q10_Part_10', 'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13',
#        'Q10_Part_14', 'Q10_Part_15', 'Q10_Part_16', 'Q10_OTHER'],
#       dtype='object')

# %%
kaggle_csv.columns
# Out:
# Index(['index', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3', 'Q18_Part_4',
#        'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1', 'Q19_Part_2',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=213)

# %%
data_txt.columns
# Out:
# Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13', 'Q15', 'Q20',
#        'Q21', 'Q22', 'Q23', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41', 'Q7', 'Q9',
#        'Q12', 'Q14', 'Q16', 'Q17', 'Q24', 'Q32', 'Q34'],
#       dtype='object')

# %%
data_xml.columns
# Out:
# Index(['level_0', 'index', 'time', 'age', 'gender'], dtype='object')

# %%
#concluimos que todos tienen el mismo número de filas, uniremos por columnas

#orden deseado para el archivo

data_xml 
data_txt
data_csv
kaggle_csv

# %%
primer_merge = data_xml.merge(data_txt, how='outer',on='index')
primer_merge.head()
# Out:
#    level_0  index  time    age gender         Q3                 Q4  \
# 0        0      0   910  50-54    Man      India  Bachelor’s degree
# 1        1      1   784  50-54    Man  Indonesia    Master’s degree
# 2        2      2   924  22-24    Man   Pakistan    Master’s degree
# 3        3      3   575  45-49    Man     Mexico    Doctoral degree
# 4        4      4   781  45-49    Man      India    Doctoral degree
#
#                         Q5          Q6      Q8  ...  \
# 0                    Other  5-10 years  Python  ...
# 1  Program/Project Manager   20+ years  Python  ...
# 2        Software Engineer   1-3 years  Python  ...
# 3       Research Scientist   20+ years  Python  ...
# 4                    Other   < 1 years  Python  ...
#
#                                                  Q41                  Q7  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
# ...

# %%
primer_merge.shape #mantiene filas  y aumentó columnas de ambos df
# Out:
# (25973, 31)

# %%
segundo_merge = primer_merge.merge(data_csv, how='outer', on= 'index')
segundo_merge.head()
# Out:
#    level_0  index  time    age gender         Q3                 Q4  \
# 0        0      0   910  50-54    Man      India  Bachelor’s degree
# 1        1      1   784  50-54    Man  Indonesia    Master’s degree
# 2        2      2   924  22-24    Man   Pakistan    Master’s degree
# 3        3      3   575  45-49    Man     Mexico    Doctoral degree
# 4        4      4   781  45-49    Man      India    Doctoral degree
#
#                         Q5          Q6      Q8  ... Q10_Part_8 Q10_Part_9  \
# 0                    Other  5-10 years  Python  ...        NaN        NaN
# 1  Program/Project Manager   20+ years  Python  ...        NaN        NaN
# 2        Software Engineer   1-3 years  Python  ...        NaN        NaN
# 3       Research Scientist   20+ years  Python  ...        NaN        NaN
# 4                    Other   < 1 years  Python  ...        NaN        NaN
#
#   Q10_Part_10           Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14  \
# ...

# %%
segundo_merge.shape
# Out:
# (25973, 48)

# %%
df_final= segundo_merge.merge(kaggle_csv, how='outer', on='index')
df_final.head()
# Out:
#    level_0  index  time    age gender         Q3                 Q4  \
# 0        0      0   910  50-54    Man      India  Bachelor’s degree
# 1        1      1   784  50-54    Man  Indonesia    Master’s degree
# 2        2      2   924  22-24    Man   Pakistan    Master’s degree
# 3        3      3   575  45-49    Man     Mexico    Doctoral degree
# 4        4      4   781  45-49    Man      India    Doctoral degree
#
#                         Q5          Q6      Q8  ... Q38_B_Part_3 Q38_B_Part_4  \
# 0                    Other  5-10 years  Python  ...          NaN          NaN
# 1  Program/Project Manager   20+ years  Python  ...          NaN          NaN
# 2        Software Engineer   1-3 years  Python  ...          NaN          NaN
# 3       Research Scientist   20+ years  Python  ...          NaN          NaN
# 4                    Other   < 1 years  Python  ...          NaN          NaN
#
#     Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7 Q38_B_Part_8 Q38_B_Part_9  \
# ...

# %%
df_final.shape
# Out:
# (25973, 260)

# %%
df_final.to_csv('./datos/df_unido.csv')

# %%
df_final.to_csv('./datos/df_unido_copia.csv')
